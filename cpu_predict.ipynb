# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
import tensorflow as tf
print("GPU device:", tf.test.gpu_device_name())
# Out:
# 2026-02-23 17:31:44.425863: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-23 17:31:44.457483: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-23 17:31:45.210837: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# GPU device:
# 2026-02-23 17:31:46.071001: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
import tensorflow as tf
import cv2
import numpy as np
import os
from tensorflow.keras.applications.convnext import preprocess_input

IMG_SIZE = 128

with tf.device('/CPU:0'):
    model = tf.keras.models.load_model("sinhala_convnext_full.keras")

print("Model loaded on CPU")

CLASS_NAMES = sorted(os.listdir("dataset_processed"))
print("Classes:", CLASS_NAMES)


def predict_image(img_path):
    img = cv2.imread(img_path)

    if img is None:
        raise ValueError("Image not found")

    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    img = img.astype(np.float32)
    img = preprocess_input(img)
    img = np.expand_dims(img, axis=0)

    with tf.device('/CPU:0'):
        preds = model.predict(img, verbose=0)

    class_index = np.argmax(preds)
    confidence = np.max(preds)

    predicted_label = CLASS_NAMES[class_index]

    return predicted_label, confidence


SEGMENTED_DIR = "segmentation_output"

for file in os.listdir(SEGMENTED_DIR):
    img_path = os.path.join(SEGMENTED_DIR, file)

    label, conf = predict_image(img_path)
    print(f"{file} → {label} ({conf*100:.2f}%)")
# Out:
# 2026-02-23 17:31:48.814679: E tensorflow/core/util/util.cc:131] oneDNN supports DT_HALF only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# /home/ndsel2004/miniconda3/envs/sinhala-gpu/lib/python3.13/site-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 698 variables whereas the saved optimizer has 702 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Model loaded on CPU
# Classes: ['ක', 'ග', 'ත', 'න', 'ප', 'ම', 'ර', 'ල', 'ස', 'හ']
# 2026-02-23 17:31:55.315862: I external/local_xla/xla/service/service.cc:163] XLA service 0x7ec988012ee0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2026-02-23 17:31:55.315884: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): Host, Default Version
# 2026-02-23 17:31:55.392149: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771848116.757103   13105 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# char_2.png → ර (82.89%)
# char_1.png → ර (97.03%)

# %%
print(tf.config.experimental.get_device_details(
    tf.config.list_logical_devices()[0]
))

# %%
print("GPU device:", tf.test.gpu_device_name())
# Out:
# GPU device:
